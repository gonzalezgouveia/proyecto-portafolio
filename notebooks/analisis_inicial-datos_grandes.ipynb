# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-578ae2fe1bfb> in <module>
#       1 import pandas as pd
# ----> 2 import geopandas as gpd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
df_datos = pd.read_csv('./../data/datos_grandes.csv', delimiter = ';')

# %%
datos_grandes.head(5)
# Out:
#    Cedula  Circunscripcion        Comuna  DV  Edad Nacionalidad  \
# 0       0        Coyhaique     Coyhaique   0    22      chilena
# 1       0        El Puerto    Valparaiso   0    89      chilena
# 2       0          Iquique       Iquique   0    99      chilena
# 3       0    Rio Tranquilo    Rio Ibañez   0    22      chilena
# 4       0        El Puerto    Valparaiso   0    95      chilena
# 5       0         Forestal  Viña Del Mar   0    31      chilena
# 6       0        El Centro      Santiago   0   106      chilena
# 7       0      La Cisterna   La Cisterna   0   100      chilena
# 8       0             Lota          Lota   0   105      chilena
# 9       0  Ranquil (Ñipas)       Ranquil   0    75      chilena
#
#   Pais Domicilio Pais Nacimiento                                     Partido  \
# 0          Chile           Chile  [130] FEDERACION REGIONALISTA VERDE SOCIAL
# 1          Chile           Chile                                 SIN PARTIDO
# ...

# %%
# Cargar la capa temática
map_data = gpd.read_file('data/santiago.geojson')
map_data.head()
